# %%
# %load_ext autoreload
# %autoreload 2

import numpy as np
import pandas as pd
import torch

from prism.config import PROCESSED_DATA_DIR, MODELS_DIR
from prism.legacy import normalise, modelStats
from prism.maskedmlp import train_mlp_batched, mlpmask_pytorch, generate_mask
from prism.save_models import save_mlp, save_lasso, save_prn
from prism.partial_responses import partial_responses
from prism.nomogram import nomogram
from prism.lasso import lasso
from prism.device_tools import get_device, print_tensor_info
# Out:
# 2024-08-14 10:01:53.878 | INFO     | prism.config:<module>:11 - PROJ_ROOT path is: C:\Users\localuser\PRiSM\prism_github

# %%
# %reload_ext autoreload

# %% [markdown]
# ## Set computation device and parameters

# %%
# By default, assign device according to CUDA > MPS > CPU
device = get_device()
print(f"Using device: {device}")
# Out:
# Using device: cuda

# %%
# Force device to be CPU
device = 'cpu'
print(f"Using device: {device}")
# Out:
# Using device: cpu

# %%
# Parameters
method = 'lebesgue'
SAVE_MODELS = False

seed = 257
np.random.seed(seed)
torch.manual_seed(seed)

# %% [markdown]
# ## Load and preprocess data

# %%
data_train = pd.read_csv(PROCESSED_DATA_DIR.joinpath('imputed_dataset1_train.csv'))
data_test = pd.read_csv(PROCESSED_DATA_DIR.joinpath('imputed_dataset1_test.csv'))
data_val = pd.read_csv(PROCESSED_DATA_DIR.joinpath('imputed_dataset1_val.csv'))

data_train_test = pd.concat([data_train,data_test]) # used for axis annotation in some plotting functions

# drop id column
data_train.drop('trr_id_code',axis=1,inplace=True)
data_test.drop('trr_id_code',axis=1,inplace=True)
data_val.drop('trr_id_code',axis=1,inplace=True)

target_col = 'oneyearmort'

x_train0 = data_train.drop(target_col,axis=1)
y_train = data_train[target_col]

x_test0 = data_test.drop(target_col,axis=1)
y_test = data_test[target_col]

x_val0 = data_val.drop(target_col,axis=1)
y_val = data_val[target_col]

[x_train,x_test] = normalise(x_train0,x_test0)
x_val = normalise(x_val0)

x_train_tensor = torch.tensor(x_train.values, dtype=torch.float32)
x_test_tensor = torch.tensor(x_test.values, dtype=torch.float32)
x_val_tensor = torch.tensor(x_val.values, dtype=torch.float32)

x_train0_median = x_train0.median().values
x_train0_std = x_train0.std().values

# %%
feature_names = [
    'don age',
    'don isch time min',
    'rec age yr',
    'rec creat',
    'rec infect 2wk',
    'rec vent',
    'rec sex',
    'tx year',
    'ICM',
    'NICM',
    'prior tx'
]

# %% [markdown]
# ## Train MLP

# %%
mlp_params = {
    'n_hidden': 10,
    'weight_decay': 1e-5,
    'lr': 0.001,
    'patience': 50,
    'tolerance': 0.0001,
    'batch_size': 1024,
    'device': device,
    'seed': seed
}

mlp = train_mlp_batched(x_train, y_train, x_test, y_test, **mlp_params)
# Out:
# Epoch 0: Train loss 0.6690, Val loss 0.6166
# Epoch 1: Train loss 0.5749, Val loss 0.5303
# Epoch 2: Train loss 0.5062, Val loss 0.4680
# Epoch 3: Train loss 0.4573, Val loss 0.4224
# Epoch 4: Train loss 0.4240, Val loss 0.3906
# Epoch 5: Train loss 0.4014, Val loss 0.3693
# Epoch 6: Train loss 0.3869, Val loss 0.3563
# Epoch 7: Train loss 0.3782, Val loss 0.3485
# Epoch 8: Train loss 0.3726, Val loss 0.3440
# Epoch 9: Train loss 0.3694, Val loss 0.3416
# Epoch 10: Train loss 0.3667, Val loss 0.3402
# Epoch 11: Train loss 0.3653, Val loss 0.3395
# Epoch 12: Train loss 0.3644, Val loss 0.3393
# Epoch 122: Train loss 0.3535, Val loss 0.3374
# Epoch 123: Train loss 0.3536, Val loss 0.3377
# Epoch 124: Train loss 0.3527, Val loss 0.3378
# Epoch 125: Train loss 0.3535, Val loss 0.3378
# Epoch 126: Train loss 0.3532, Val loss 0.3377
# Epoch 127: Train loss 0.3538, Val loss 0.3380
# Epoch 128: Train loss 0.3536, Val loss 0.3378
# Epoch 129: Train loss 0.3537, Val loss 0.3378
# Epoch 130: Train loss 0.3527, Val loss 0.3378
# Epoch 131: Train loss 0.3532, Val loss 0.3376
# Epoch 132: Train loss 0.3534, Val loss 0.3377
# Epoch 133: Train loss 0.3533, Val loss 0.3378
# Epoch 134: Train loss 0.3529, Val loss 0.3377
# Epoch 135: Train loss 0.3537, Val loss 0.3379
# Epoch 136: Train loss 0.3535, Val loss 0.3380
# Stopping early at epoch 87

# %% [markdown]
# # Evaluate MLP

# %%
y_test_blackbox = mlp.predict(x_test_tensor).cpu().numpy()
y_val_blackbox = mlp.predict(x_val_tensor).cpu().numpy()

mlp_metrics_test = modelStats(y_test_blackbox, y_test, y_train, ROC=True, mdlCalibration=True, metricNames=True, auc_ci=True)
modelStats(y_val_blackbox, y_val, y_train, ROC=True, mdlCalibration=True, metricNames=True, auc_ci=True);
# Out:
# -------- Metrics --------
# prevalence: 0.123
# sensitivity: 0.241
# specificity: 0.864
# accuracy: 0.797
# ppv: 0.175
# auc score: 0.601
# auc lower ci: 0.577
# auc upper ci: 0.623
# -------------------------
# -------- Metrics --------
# prevalence: 0.123
# sensitivity: 0.667
# specificity: 0.489
# accuracy: 0.507
# ppv: 0.126
# auc score: 0.606
# auc lower ci: 0.582
# auc upper ci: 0.631
# -------------------------

# %%
# Save MLP
if SAVE_MODELS:
    save_mlp(mlp, mlp_params, mlp_metrics_test, MODELS_DIR)

# %% [markdown]
# # MLP LASSO

# %%
partial_responses_train, partial_responses_test, bivariate_inputs = partial_responses(
    x_train_tensor,
    x_test_tensor,
    mlp,
    method=method,
    device=device,
    batch_size=256
)
# Out:
# Univariate feature 0
# Univariate feature 1
# Univariate feature 2
# Univariate feature 3
# Univariate feature 4
# Univariate feature 5
# Univariate feature 6
# Univariate feature 7
# Univariate feature 8
# Univariate feature 9
# Univariate feature 10
# Bivariate feature 0,1
# Bivariate feature 0,2
# Bivariate feature 0,3
# Bivariate feature 0,4
# Bivariate feature 0,5
# Bivariate feature 0,6
# Bivariate feature 0,7
# Bivariate feature 0,8
# Bivariate feature 0,9
# Bivariate feature 0,10
# Bivariate feature 1,2
# Bivariate feature 1,3
# Bivariate feature 1,4
# Bivariate feature 1,5
# Bivariate feature 1,6
# Bivariate feature 1,7
# Bivariate feature 1,8
# Bivariate feature 1,9
# Bivariate feature 1,10
# Bivariate feature 2,3
# Bivariate feature 2,4
# Bivariate feature 2,5
# Bivariate feature 2,6
# Bivariate feature 2,7
# Bivariate feature 2,8
# Bivariate feature 2,9
# Bivariate feature 2,10
# Bivariate feature 3,4
# Bivariate feature 3,5
# Bivariate feature 3,6
# Bivariate feature 3,7
# Bivariate feature 3,8
# Bivariate feature 3,9
# Bivariate feature 3,10
# Bivariate feature 4,5
# Bivariate feature 4,6
# Bivariate feature 4,7
# Bivariate feature 4,8
# Bivariate feature 4,9
# Bivariate feature 4,10
# Bivariate feature 5,6
# Bivariate feature 5,7
# Bivariate feature 5,8
# Bivariate feature 5,9
# Bivariate feature 5,10
# Bivariate feature 6,7
# Bivariate feature 6,8
# Bivariate feature 6,9
# Bivariate feature 6,10
# Bivariate feature 7,8
# Bivariate feature 7,9
# Bivariate feature 7,10
# Bivariate feature 8,9
# Bivariate feature 8,10
# Bivariate feature 9,10
# Univariate feature 0
# Univariate feature 1
# Univariate feature 2
# Univariate feature 3
# Univariate feature 4
# Univariate feature 5
# Univariate feature 6
# Univariate feature 7
# Univariate feature 8
# Univariate feature 9
# Univariate feature 10
# Bivariate feature 0,1
# Bivariate feature 0,2
# Bivariate feature 0,3
# Bivariate feature 0,4
# Bivariate feature 0,5
# Bivariate feature 0,6
# Bivariate feature 0,7
# Bivariate feature 0,8
# Bivariate feature 0,9
# Bivariate feature 0,10
# Bivariate feature 1,2
# Bivariate feature 1,3
# Bivariate feature 1,4
# Bivariate feature 1,5
# Bivariate feature 1,6
# Bivariate feature 1,7
# Bivariate feature 1,8
# Bivariate feature 1,9
# Bivariate feature 1,10
# Bivariate feature 2,3
# Bivariate feature 2,4
# Bivariate feature 2,5
# Bivariate feature 2,6
# Bivariate feature 2,7
# Bivariate feature 2,8
# Bivariate feature 2,9
# Bivariate feature 2,10
# Bivariate feature 3,4
# Bivariate feature 3,5
# Bivariate feature 3,6
# Bivariate feature 3,7
# Bivariate feature 3,8
# Bivariate feature 3,9
# Bivariate feature 3,10
# Bivariate feature 4,5
# Bivariate feature 4,6
# Bivariate feature 4,7
# Bivariate feature 4,8
# Bivariate feature 4,9
# Bivariate feature 4,10
# Bivariate feature 5,6
# Bivariate feature 5,7
# Bivariate feature 5,8
# Bivariate feature 5,9
# Bivariate feature 5,10
# Bivariate feature 6,7
# Bivariate feature 6,8
# Bivariate feature 6,9
# Bivariate feature 6,10
# Bivariate feature 7,8
# Bivariate feature 7,9
# Bivariate feature 7,10
# Bivariate feature 8,9
# Bivariate feature 8,10
# Bivariate feature 9,10

# %%
# %reload_ext autoreload
lasso_results = lasso(
    partial_responses_train, 
    partial_responses_test, 
    y_train, 
    y_test, 
    bivariate_inputs,
    feature_names=feature_names,
    nlambda=25, 
    min_lambda=0.1,
    max_lambda=100,
    tol=1e-4,
    batch_size=2
)
# Out:
# <pre style='font-family: monospace;'>Index Lambda     Train AUC  Test AUC   Train Dev   Test Dev    Train Loss Test Loss  β_univ>0.1 β_biv>0.1
# -------------------------------------------------------------------------------------------------------------------
# 0      100.00000  0.6202    0.5808    22717.0329  4227.9714   0.3627    0.3454    4          0
# 1      74.98942   0.6350    0.5875    22575.0420  4380.0389   0.3605    0.3578    5          0
# 2      56.23413   0.6419    0.5926    22466.4184  4588.0446   0.3587    0.3748    6          0
# 3      42.16965   0.6448    0.5965    22398.6233  4793.7574   0.3576    0.3916    7          0
# 4      31.62278   0.6459    0.5985    22359.1701  4969.3292   0.3570    0.4060    7          0
# 5      23.71374   0.6480    0.6007    22318.7319  5229.1058   0.3564    0.4272    9          0
# 6      17.78279   0.6495    0.6027    22287.6977  5502.7247   0.3559    0.4496    9          0
# 7      13.33521   0.6501    0.6036    22270.2706  5717.0217   0.3556    0.4671    9          0
# 8      10.00000   0.6511    0.6039   *22251.5708  5820.2220   0.3553    0.4755    9          1
# 9      7.49894    0.6520    0.6038    22234.5384  5969.2108   0.3550    0.4877    10         1
# 10     5.62341    0.6528    0.6033    22217.5320  6122.5739   0.3547    0.5002    11         2
# 11     4.21697    0.6534    0.6029    22204.7921  6100.7926   0.3545    0.4984    11         3
# 12     3.16228    0.6539    0.6025    22195.4418  5956.1053   0.3544    0.4866    11         4
# 13     2.37137    0.6544    0.6021    22184.1585  5392.1871   0.3542    0.4405    11         8
# 14     1.77828    0.6553    0.6020    22164.5149  4174.5582  *0.3539    0.3411   *11         14
# 15     1.33352    0.6561    0.6022    22148.7988  4764.0758   0.3536    0.3892    11         20
# 16     1.00000    0.6569    0.6024    22134.6875  7409.2569   0.3534    0.6053    11         24
# 17     0.74989    0.6574    0.6024    22125.1068  12419.3537  0.3533    1.0147    11         26
# 18     0.56234    0.6578    0.6026    22117.3284  20249.4033  0.3531    1.6544    11         30
# 19     0.42170    0.6582    0.6025    22110.8574  24578.5241  0.3530    2.0080    11         34
# 20     0.31623    0.6584    0.6022    22106.2296  31824.7723  0.3530    2.6001    11         36
# 21     0.23714    0.6587    0.6020    22102.3309  36608.8285  0.3529    2.9909    11         40
# 22     0.17783    0.6588    0.6014    22099.7603  42560.9426  0.3529    3.4772    11         40
# 23     0.13335    0.6589    0.6009    22097.8576  49783.5367  0.3528    4.0673    11         43
# 24     0.10000    0.6591   *0.6002    22096.1134 *53675.7600  0.3528   *4.3853    11         45        </pre>

# %%
lasso_results.plot_lambda_path()

# %%
lasso_results.select_lambda(8)
lasso_results.plot_feature_importance()

# %%
# %reload_ext autoreload
# Note: The prPlots function is not yet available in the new implementation.
# We'll use the new nomogram function instead.
nomogram_results = nomogram(
    lasso_results,
    x_train_tensor,
    x_train0.median().values,
    x_train0.std().values,
    mlp,
    n_steps=15,
    sd_scale=2,
    method=method,
    device=device,
    categorical_threshold=15,
    subtract_univariate=True
);

# %%
#  test with more features
lasso_results.select_lambda(24)

# %%
# %reload_ext autoreload
nomogram_results = nomogram(
    lasso_results,
    x_train_tensor,
    x_train0.median().values,
    x_train0.std().values,
    mlp,
    n_steps=15,
    sd_scale=2,
    method=method,
    device=device,
    categorical_threshold=15,
    subtract_univariate=True
)

# %%
# return to previously selected lambda
lasso_results.select_lambda(8)

# %% [markdown]
# # Train the Partial Response Network

# %%
mask, n_features = lasso_results.get_mask()
# Out:
# Active features: ['don age', 'don isch time min', 'rec age yr', 'rec creat', 'rec infect 2wk', 'rec vent', 'rec sex', 'tx year', 'NICM', 'rec age yr : ICM']

# Epoch 119, Training loss 0.35492992401123047, Validation loss 0.3369028866291046
# Epoch 120, Training loss 0.35492652654647827, Validation loss 0.33693641424179077
# Epoch 121, Training loss 0.3549236059188843, Validation loss 0.3369506001472473
# Epoch 122, Training loss 0.35492080450057983, Validation loss 0.3369424343109131
# Epoch 123, Training loss 0.35491788387298584, Validation loss 0.3369179666042328
# Epoch 124, Training loss 0.35491499304771423, Validation loss 0.3368891179561615
# Epoch 125, Training loss 0.3549124002456665, Validation loss 0.33686843514442444
# Epoch 126, Training loss 0.35491010546684265, Validation loss 0.33686426281929016
# Epoch 127, Training loss 0.3549078106880188, Validation loss 0.3368780016899109
# Epoch 128, Training loss 0.35490548610687256, Validation loss 0.3369044065475464
# Epoch 129, Training loss 0.3549032211303711, Validation loss 0.3369336426258087
# Epoch 130, Training loss 0.35490119457244873, Validation loss 0.3369556963443756
# Epoch 131, Training loss 0.35489925742149353, Validation loss 0.3369642198085785
# Epoch 132, Training loss 0.3548973500728607, Validation loss 0.33695870637893677
# Epoch 133, Training loss 0.35489538311958313, Validation loss 0.3369443416595459
# Epoch 134, Training loss 0.3548935055732727, Validation loss 0.3369292616844177
# Epoch 135, Training loss 0.3548917770385742, Validation loss 0.33692100644111633
# Epoch 136, Training loss 0.3548901379108429, Validation loss 0.3369234800338745
# Epoch 137, Training loss 0.3548884093761444, Validation loss 0.33693575859069824
# Early stopping! Epoch 137
# Best model at epoch 37

# %% [markdown]
# # Evaluate the Partial Response Network

# %%
y_test_prn_pytorch = prn.predict(x_test_tensor, device=device).cpu().numpy()
y_val_prn_pytorch = prn.predict(x_val_tensor, device=device).cpu().numpy()

prn_metrics_test = modelStats(y_test_prn_pytorch, y_test, y_train, auc_ci=True)
modelStats(y_val_prn_pytorch, y_val, y_train, auc_ci=True)
# Out:
# -------- Metrics --------
# prevalence: 0.123
# sensitivity: 0.235
# specificity: 0.867
# accuracy: 0.799
# ppv: 0.174
# auc score: 0.602
# auc lower ci: 0.578
# auc upper ci: 0.622
# -------------------------
# -------- Metrics --------
# prevalence: 0.123
# sensitivity: 0.639
# specificity: 0.512
# accuracy: 0.524
# ppv: 0.126
# auc score: 0.61
# auc lower ci: 0.583
# auc upper ci: 0.632
# -------------------------
# {'prevalence': 0.123,
#  'sensitivity': 0.639,
#  'specificity': 0.512,
#  'accuracy': 0.524,
#  'ppv': 0.126,
#  'auc score': 0.61,
#  'auc lower ci': '0.583',
#  'auc upper ci': '0.632'}

# %% [markdown]
# # LASSO on the Partial Response Network

# %%
# Check current device memory usage
print_tensor_info()
# Out:
# Tensors currently in memory:
# Name: x_train_tensor, Type: Tensor, Size: torch.Size([31315, 11]), Device: cpu, Dtype: torch.float32
# Name: x_test_tensor, Type: Tensor, Size: torch.Size([6120, 11]), Device: cpu, Dtype: torch.float32
# Name: x_val_tensor, Type: Tensor, Size: torch.Size([4750, 11]), Device: cpu, Dtype: torch.float32
# Name: Unknown, Type: NestedTensor, Size: torch.Size([1, j0, 3]), Device: meta, Dtype: torch.float32
# Name: Unknown, Type: Tensor, Size: torch.Size([3, 3]), Device: meta, Dtype: torch.float32
# Name: Unknown, Type: Tensor, Size: torch.Size([2]), Device: meta, Dtype: torch.int64
# Name: Unknown, Type: Tensor, Size: torch.Size([10, 11]), Device: cpu, Dtype: torch.float32
# Name: Unknown, Type: Tensor, Size: torch.Size([10]), Device: cpu, Dtype: torch.float32
# Name: Unknown, Type: Tensor, Size: torch.Size([1, 10]), Device: cpu, Dtype: torch.float32
# Name: Unknown, Type: Tensor, Size: torch.Size([1]), Device: cpu, Dtype: torch.float32
# Name: Unknown, Type: Parameter, Size: torch.Size([10, 11]), Device: cpu, Dtype: torch.float32
# Name: Unknown, Type: Parameter, Size: torch.Size([10]), Device: cpu, Dtype: torch.float32
# Name: Unknown, Type: Parameter, Size: torch.Size([1, 10]), Device: cpu, Dtype: torch.float32
# Name: Unknown, Type: Parameter, Size: torch.Size([1]), Device: cpu, Dtype: torch.float32
# Name: Unknown, Type: Tensor, Size: torch.Size([6120, 1]), Device: cpu, Dtype: torch.float32
# Name: Unknown, Type: Tensor, Size: torch.Size([4750, 1]), Device: cpu, Dtype: torch.float32
# Name: Unknown, Type: Tensor, Size: torch.Size([32066560, 1]), Device: cpu, Dtype: torch.float32
# Name: Unknown, Type: Tensor, Size: torch.Size([1024, 31315, 11]), Device: cpu, Dtype: torch.float32
# Name: partial_responses_train, Type: Tensor, Size: torch.Size([31315, 66]), Device: cpu, Dtype: torch.float32
# Name: partial_responses_test, Type: Tensor, Size: torch.Size([6120, 66]), Device: cpu, Dtype: torch.float32
# Name: Unknown, Type: Tensor, Size: torch.Size([31315, 11]), Device: cpu, Dtype: torch.float32
# Name: Unknown, Type: Tensor, Size: torch.Size([31315, 55]), Device: cpu, Dtype: torch.float32
# Name: Unknown, Type: Tensor, Size: torch.Size([32066560, 11]), Device: cpu, Dtype: torch.float32
# Name: Unknown, Type: Tensor, Size: torch.Size([32066560]), Device: cpu, Dtype: torch.float32
# Name: Unknown, Type: Tensor, Size: torch.Size([1024]), Device: cpu, Dtype: torch.float32
# Name: Unknown, Type: Tensor, Size: torch.Size([15]), Device: cpu, Dtype: torch.float32
# Name: Unknown, Type: Tensor, Size: torch.Size([15]), Device: cpu, Dtype: torch.float32
# Name: Unknown, Type: Tensor, Size: torch.Size([15]), Device: cpu, Dtype: torch.float32
# Name: Unknown, Type: Tensor, Size: torch.Size([15]), Device: cpu, Dtype: torch.float32
# Name: Unknown, Type: Tensor, Size: torch.Size([2]), Device: cpu, Dtype: torch.float32
# Name: Unknown, Type: Tensor, Size: torch.Size([2]), Device: cpu, Dtype: torch.float32
# Name: Unknown, Type: Tensor, Size: torch.Size([2]), Device: cpu, Dtype: torch.float32
# Name: Unknown, Type: Tensor, Size: torch.Size([15]), Device: cpu, Dtype: torch.float32
# Name: Unknown, Type: Tensor, Size: torch.Size([2]), Device: cpu, Dtype: torch.float32
# Name: Unknown, Type: Tensor, Size: torch.Size([2]), Device: cpu, Dtype: torch.float32
# Name: Unknown, Type: Tensor, Size: torch.Size([2]), Device: cpu, Dtype: torch.float32
# Name: Unknown, Type: Tensor, Size: torch.Size([225]), Device: cpu, Dtype: torch.float32
# Name: Unknown, Type: Tensor, Size: torch.Size([225]), Device: cpu, Dtype: torch.float32
# Name: Unknown, Type: Tensor, Size: torch.Size([225]), Device: cpu, Dtype: torch.float32
# Name: Unknown, Type: Tensor, Size: torch.Size([30]), Device: cpu, Dtype: torch.float32
# Name: Unknown, Type: Tensor, Size: torch.Size([30]), Device: cpu, Dtype: torch.float32
# Name: Unknown, Type: Tensor, Size: torch.Size([30]), Device: cpu, Dtype: torch.float32
# Name: Unknown, Type: Tensor, Size: torch.Size([225]), Device: cpu, Dtype: torch.float32
# Name: Unknown, Type: Tensor, Size: torch.Size([30]), Device: cpu, Dtype: torch.float32
# Name: Unknown, Type: Tensor, Size: torch.Size([30]), Device: cpu, Dtype: torch.float32
# Name: Unknown, Type: Tensor, Size: torch.Size([30]), Device: cpu, Dtype: torch.float32
# Name: Unknown, Type: Tensor, Size: torch.Size([225]), Device: cpu, Dtype: torch.float32
# Name: Unknown, Type: Tensor, Size: torch.Size([225]), Device: cpu, Dtype: torch.float32
# Name: Unknown, Type: Tensor, Size: torch.Size([30]), Device: cpu, Dtype: torch.float32
# Name: Unknown, Type: Tensor, Size: torch.Size([30]), Device: cpu, Dtype: torch.float32
# Name: Unknown, Type: Tensor, Size: torch.Size([30]), Device: cpu, Dtype: torch.float32
# Name: Unknown, Type: Tensor, Size: torch.Size([225]), Device: cpu, Dtype: torch.float32
# Name: Unknown, Type: Tensor, Size: torch.Size([30]), Device: cpu, Dtype: torch.float32
# Name: Unknown, Type: Tensor, Size: torch.Size([30]), Device: cpu, Dtype: torch.float32
# Name: Unknown, Type: Tensor, Size: torch.Size([30]), Device: cpu, Dtype: torch.float32
# Name: Unknown, Type: Tensor, Size: torch.Size([225]), Device: cpu, Dtype: torch.float32
# Name: Unknown, Type: Tensor, Size: torch.Size([30]), Device: cpu, Dtype: torch.float32
# Name: Unknown, Type: Tensor, Size: torch.Size([30]), Device: cpu, Dtype: torch.float32
# Name: Unknown, Type: Tensor, Size: torch.Size([30]), Device: cpu, Dtype: torch.float32
# Name: Unknown, Type: Tensor, Size: torch.Size([225]), Device: cpu, Dtype: torch.float32
# Name: Unknown, Type: Tensor, Size: torch.Size([30]), Device: cpu, Dtype: torch.float32
# Name: Unknown, Type: Tensor, Size: torch.Size([30]), Device: cpu, Dtype: torch.float32
# Name: Unknown, Type: Tensor, Size: torch.Size([30]), Device: cpu, Dtype: torch.float32
# Name: Unknown, Type: Tensor, Size: torch.Size([30]), Device: cpu, Dtype: torch.float32
# Name: Unknown, Type: Tensor, Size: torch.Size([30]), Device: cpu, Dtype: torch.float32
# Name: Unknown, Type: Tensor, Size: torch.Size([30]), Device: cpu, Dtype: torch.float32
# Name: Unknown, Type: Tensor, Size: torch.Size([225]), Device: cpu, Dtype: torch.float32
# Name: Unknown, Type: Tensor, Size: torch.Size([30]), Device: cpu, Dtype: torch.float32
# Name: Unknown, Type: Tensor, Size: torch.Size([30]), Device: cpu, Dtype: torch.float32
# Name: Unknown, Type: Tensor, Size: torch.Size([30]), Device: cpu, Dtype: torch.float32
# Name: Unknown, Type: Tensor, Size: torch.Size([4]), Device: cpu, Dtype: torch.float32
# Name: Unknown, Type: Tensor, Size: torch.Size([4]), Device: cpu, Dtype: torch.float32
# Name: Unknown, Type: Tensor, Size: torch.Size([30]), Device: cpu, Dtype: torch.float32
# Name: Unknown, Type: Tensor, Size: torch.Size([4]), Device: cpu, Dtype: torch.float32
# Name: Unknown, Type: Tensor, Size: torch.Size([4]), Device: cpu, Dtype: torch.float32
# Name: Unknown, Type: Tensor, Size: torch.Size([4]), Device: cpu, Dtype: torch.float32
# Name: Unknown, Type: Tensor, Size: torch.Size([4]), Device: cpu, Dtype: torch.float32
# Name: Unknown, Type: Tensor, Size: torch.Size([30]), Device: cpu, Dtype: torch.float32
# Name: Unknown, Type: Tensor, Size: torch.Size([4]), Device: cpu, Dtype: torch.float32
# Name: Unknown, Type: Tensor, Size: torch.Size([4]), Device: cpu, Dtype: torch.float32
# Name: Unknown, Type: Tensor, Size: torch.Size([4]), Device: cpu, Dtype: torch.float32
# Name: Unknown, Type: Tensor, Size: torch.Size([30]), Device: cpu, Dtype: torch.float32
# Name: Unknown, Type: Tensor, Size: torch.Size([4]), Device: cpu, Dtype: torch.float32
# Name: Unknown, Type: Tensor, Size: torch.Size([4]), Device: cpu, Dtype: torch.float32
# Name: Unknown, Type: Tensor, Size: torch.Size([4]), Device: cpu, Dtype: torch.float32
# Name: Unknown, Type: Tensor, Size: torch.Size([30]), Device: cpu, Dtype: torch.float32
# Name: Unknown, Type: Tensor, Size: torch.Size([30]), Device: cpu, Dtype: torch.float32
# Name: Unknown, Type: Tensor, Size: torch.Size([30]), Device: cpu, Dtype: torch.float32
# Name: Unknown, Type: Tensor, Size: torch.Size([4]), Device: cpu, Dtype: torch.float32
# Name: Unknown, Type: Tensor, Size: torch.Size([4]), Device: cpu, Dtype: torch.float32
# Name: Unknown, Type: Tensor, Size: torch.Size([4]), Device: cpu, Dtype: torch.float32
# Name: Unknown, Type: Tensor, Size: torch.Size([15]), Device: cpu, Dtype: torch.float32
# Name: Unknown, Type: Tensor, Size: torch.Size([15]), Device: cpu, Dtype: torch.float32
# Name: Unknown, Type: Tensor, Size: torch.Size([15]), Device: cpu, Dtype: torch.float32
# Name: Unknown, Type: Tensor, Size: torch.Size([15]), Device: cpu, Dtype: torch.float32
# Name: Unknown, Type: Tensor, Size: torch.Size([2]), Device: cpu, Dtype: torch.float32
# Name: Unknown, Type: Tensor, Size: torch.Size([2]), Device: cpu, Dtype: torch.float32
# Name: Unknown, Type: Tensor, Size: torch.Size([2]), Device: cpu, Dtype: torch.float32
# Name: Unknown, Type: Tensor, Size: torch.Size([15]), Device: cpu, Dtype: torch.float32
# Name: Unknown, Type: Tensor, Size: torch.Size([2]), Device: cpu, Dtype: torch.float32
# Name: Unknown, Type: Tensor, Size: torch.Size([2]), Device: cpu, Dtype: torch.float32
# Name: Unknown, Type: Tensor, Size: torch.Size([2]), Device: cpu, Dtype: torch.float32
# Name: Unknown, Type: Tensor, Size: torch.Size([225, 2]), Device: cpu, Dtype: torch.float32
# Name: Unknown, Type: Tensor, Size: torch.Size([225, 2]), Device: cpu, Dtype: torch.float32
# Name: Unknown, Type: Tensor, Size: torch.Size([225, 2]), Device: cpu, Dtype: torch.float32
# Name: Unknown, Type: Tensor, Size: torch.Size([30, 2]), Device: cpu, Dtype: torch.float32
# Name: Unknown, Type: Tensor, Size: torch.Size([30, 2]), Device: cpu, Dtype: torch.float32
# Name: Unknown, Type: Tensor, Size: torch.Size([30, 2]), Device: cpu, Dtype: torch.float32
# Name: Unknown, Type: Tensor, Size: torch.Size([225, 2]), Device: cpu, Dtype: torch.float32
# Name: Unknown, Type: Tensor, Size: torch.Size([30, 2]), Device: cpu, Dtype: torch.float32
# Name: Unknown, Type: Tensor, Size: torch.Size([30, 2]), Device: cpu, Dtype: torch.float32
# Name: Unknown, Type: Tensor, Size: torch.Size([30, 2]), Device: cpu, Dtype: torch.float32
# Name: Unknown, Type: Tensor, Size: torch.Size([225, 2]), Device: cpu, Dtype: torch.float32
# Name: Unknown, Type: Tensor, Size: torch.Size([225, 2]), Device: cpu, Dtype: torch.float32
# Name: Unknown, Type: Tensor, Size: torch.Size([30, 2]), Device: cpu, Dtype: torch.float32
# Name: Unknown, Type: Tensor, Size: torch.Size([30, 2]), Device: cpu, Dtype: torch.float32
# Name: Unknown, Type: Tensor, Size: torch.Size([30, 2]), Device: cpu, Dtype: torch.float32
# Name: Unknown, Type: Tensor, Size: torch.Size([225, 2]), Device: cpu, Dtype: torch.float32
# Name: Unknown, Type: Tensor, Size: torch.Size([30, 2]), Device: cpu, Dtype: torch.float32
# Name: Unknown, Type: Tensor, Size: torch.Size([30, 2]), Device: cpu, Dtype: torch.float32
# Name: Unknown, Type: Tensor, Size: torch.Size([30, 2]), Device: cpu, Dtype: torch.float32
# Name: Unknown, Type: Tensor, Size: torch.Size([225, 2]), Device: cpu, Dtype: torch.float32
# Name: Unknown, Type: Tensor, Size: torch.Size([30, 2]), Device: cpu, Dtype: torch.float32
# Name: Unknown, Type: Tensor, Size: torch.Size([30, 2]), Device: cpu, Dtype: torch.float32
# Name: Unknown, Type: Tensor, Size: torch.Size([30, 2]), Device: cpu, Dtype: torch.float32
# Name: Unknown, Type: Tensor, Size: torch.Size([225, 2]), Device: cpu, Dtype: torch.float32
# Name: Unknown, Type: Tensor, Size: torch.Size([30, 2]), Device: cpu, Dtype: torch.float32
# Name: Unknown, Type: Tensor, Size: torch.Size([30, 2]), Device: cpu, Dtype: torch.float32
# Name: Unknown, Type: Tensor, Size: torch.Size([30, 2]), Device: cpu, Dtype: torch.float32
# Name: Unknown, Type: Tensor, Size: torch.Size([30, 2]), Device: cpu, Dtype: torch.float32
# Name: Unknown, Type: Tensor, Size: torch.Size([30, 2]), Device: cpu, Dtype: torch.float32
# Name: Unknown, Type: Tensor, Size: torch.Size([30, 2]), Device: cpu, Dtype: torch.float32
# Name: Unknown, Type: Tensor, Size: torch.Size([225, 2]), Device: cpu, Dtype: torch.float32
# Name: Unknown, Type: Tensor, Size: torch.Size([30, 2]), Device: cpu, Dtype: torch.float32
# Name: Unknown, Type: Tensor, Size: torch.Size([30, 2]), Device: cpu, Dtype: torch.float32
# Name: Unknown, Type: Tensor, Size: torch.Size([30, 2]), Device: cpu, Dtype: torch.float32
# Name: Unknown, Type: Tensor, Size: torch.Size([4, 2]), Device: cpu, Dtype: torch.float32
# Name: Unknown, Type: Tensor, Size: torch.Size([4, 2]), Device: cpu, Dtype: torch.float32
# Name: Unknown, Type: Tensor, Size: torch.Size([30, 2]), Device: cpu, Dtype: torch.float32
# Name: Unknown, Type: Tensor, Size: torch.Size([4, 2]), Device: cpu, Dtype: torch.float32
# Name: Unknown, Type: Tensor, Size: torch.Size([4, 2]), Device: cpu, Dtype: torch.float32
# Name: Unknown, Type: Tensor, Size: torch.Size([4, 2]), Device: cpu, Dtype: torch.float32
# Name: Unknown, Type: Tensor, Size: torch.Size([4, 2]), Device: cpu, Dtype: torch.float32
# Name: Unknown, Type: Tensor, Size: torch.Size([30, 2]), Device: cpu, Dtype: torch.float32
# Name: Unknown, Type: Tensor, Size: torch.Size([4, 2]), Device: cpu, Dtype: torch.float32
# Name: Unknown, Type: Tensor, Size: torch.Size([4, 2]), Device: cpu, Dtype: torch.float32
# Name: Unknown, Type: Tensor, Size: torch.Size([4, 2]), Device: cpu, Dtype: torch.float32
# Name: Unknown, Type: Tensor, Size: torch.Size([30, 2]), Device: cpu, Dtype: torch.float32
# Name: Unknown, Type: Tensor, Size: torch.Size([4, 2]), Device: cpu, Dtype: torch.float32
# Name: Unknown, Type: Tensor, Size: torch.Size([4, 2]), Device: cpu, Dtype: torch.float32
# Name: Unknown, Type: Tensor, Size: torch.Size([4, 2]), Device: cpu, Dtype: torch.float32
# Name: Unknown, Type: Tensor, Size: torch.Size([30, 2]), Device: cpu, Dtype: torch.float32
# Name: Unknown, Type: Tensor, Size: torch.Size([30, 2]), Device: cpu, Dtype: torch.float32
# Name: Unknown, Type: Tensor, Size: torch.Size([30, 2]), Device: cpu, Dtype: torch.float32
# Name: Unknown, Type: Tensor, Size: torch.Size([4, 2]), Device: cpu, Dtype: torch.float32
# Name: Unknown, Type: Tensor, Size: torch.Size([4, 2]), Device: cpu, Dtype: torch.float32
# Name: Unknown, Type: Tensor, Size: torch.Size([4, 2]), Device: cpu, Dtype: torch.float32
# Name: Unknown, Type: Parameter, Size: torch.Size([1]), Device: cpu, Dtype: torch.float32
# Name: Unknown, Type: Parameter, Size: torch.Size([1, 55]), Device: cpu, Dtype: torch.float32
# Name: Unknown, Type: Parameter, Size: torch.Size([55]), Device: cpu, Dtype: torch.float32
# Name: Unknown, Type: Parameter, Size: torch.Size([55, 11]), Device: cpu, Dtype: torch.float32
# Name: Unknown, Type: Tensor, Size: torch.Size([55, 11]), Device: cpu, Dtype: torch.float32
# Name: Unknown, Type: Tensor, Size: torch.Size([55, 11]), Device: cpu, Dtype: torch.float32
# Name: Unknown, Type: Tensor, Size: torch.Size([55]), Device: cpu, Dtype: torch.float32
# Name: Unknown, Type: Tensor, Size: torch.Size([1, 55]), Device: cpu, Dtype: torch.float32
# Name: Unknown, Type: Tensor, Size: torch.Size([1]), Device: cpu, Dtype: torch.float32
# Name: Unknown, Type: Tensor, Size: torch.Size([6120, 1]), Device: cpu, Dtype: torch.float32
# Name: Unknown, Type: Tensor, Size: torch.Size([4750, 1]), Device: cpu, Dtype: torch.float32
#
# Device Memory Usage:
# CUDA (GPU):
# Allocated: 0.00 GB
# Cached:    0.02 GB
# c:\Users\localuser\PRiSM\prism_github\venv_prism\Lib\site-packages\torch\distributed\distributed_c10d.py:366: UserWarning: torch.distributed.reduce_op is deprecated, please use torch.distributed.ReduceOp instead
#   warnings.warn(

# %%
# Lowering batch size to accomodate larger PRN model compared to the MLP
partial_responses_train_prn, partial_responses_test_prn, bivariate_inputs_prn = partial_responses(
    x_train_tensor,
    x_test_tensor,
    prn,
    method=method,
    device=device,
    batch_size=64
)

# %%
# %reload_ext autoreload
lasso_results_prn = lasso(
    partial_responses_train_prn, 
    partial_responses_test_prn, 
    y_train, 
    y_test, 
    bivariate_inputs_prn,
    feature_names=feature_names,
    nlambda=75, 
    min_lambda=0.1,
    max_lambda=100,
    tol=1e-4,
    batch_size=2
)

# %%
lasso_results_prn.plot_lambda_path()

# %%
lasso_results_prn.select_lambda(24)
lasso_results_prn.plot_feature_importance()

# %% [markdown]
# # Validation inference

# %%
prn_lasso = lasso_results_prn.get_selected_model()

# %% [markdown]
# TODO: update partial_responses to make exclusion of the train data (inference only) possible.

# %%
_, partial_responses_val_prn, bivariate_inputs_prn = partial_responses(
    x_train_tensor,
    x_val_tensor,
    prn,
    method=method,
    device=device,
    batch_size=256
)

# %%
y_pred_test_prn_lasso = prn_lasso.predict_proba(partial_responses_test_prn)[:, 1]
y_pred_val_prn_lasso = prn_lasso.predict_proba(partial_responses_val_prn)[:, 1]
lasso_metrics_test = modelStats(y_pred_test_prn_lasso, y_test, y_train, auc_ci=True)

# %%
modelStats(y_pred_val_prn_lasso, y_val, y_train, auc_ci=True)

# %% [markdown]
# # Partial Response Network Nomogram

# %%
nomogram(
    lasso_results_prn,
    x_train_tensor,
    x_train0.median().values,
    x_train0.std().values,
    prn,
    n_steps=15,
    sd_scale=2,
    method=method,
    device=device,
    categorical_threshold=15,
    subtract_univariate=True
);

# %% [markdown]
# ## Nomogram with more
#
# TODO: modify lasso_results to include possibility to select all features, all univariate, all bivariate (e.g. for plotting).

# %%
# test with more features
# todo add all features method to lasso_results object.
lasso_results_prn.select_lambda(74)
nomogram(
    lasso_results_prn,
    x_train_tensor,
    x_train0.median().values,
    x_train0.std().values,
    prn,
    n_steps=15,
    sd_scale=2,
    method=method,
    device=device,
    categorical_threshold=15
);
